# %%
from model import CNN, RNN,  ModelMix
from torch import nn
from data_loader import load_split_data
from torch.optim import SGD, Adam
from torch.utils.tensorboard import SummaryWriter
from utils import get_device

import json

# %%
from train_model import Train

BATCH_SIZE = 128
LEARN_RATE = 0.05
EMBEDDING_DIM = 200

with open('./datainfo.json', 'r') as f:
    data = json.load(f)  
    
vocab = data["vocab"]
vocab_size = len(vocab)
writer = SummaryWriter(comment=f"RNN-Momentum {LEARN_RATE} {BATCH_SIZE}")

trainloader, testloader = load_split_data(data, BATCH_SIZE, .2)

# %%
device = get_device()
model1 = RNN(vocab_size, EMBEDDING_DIM, 256, vocab)
model2 = CNN()
model = ModelMix(model1, model2)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = SGD(model.parameters(), lr=LEARN_RATE, momentum=0.9)

# %%
experiment = Train(model, optimizer, criterion,trainloader, testloader, writer=writer, show_matrix = True)
experiment.train_model()
# Out:
# ==== Iniciando entrenamiento ====
#
# Los parametros a usar son
#               model: ModelMix(
#   (model_text): RNN(
#     (embedding): Embedding(8669, 200, padding_idx=1)
#     (rnn): RNN(200, 256, batch_first=True, bidirectional=True)
#     (label): Linear(in_features=512, out_features=256, bias=True)
#   )
#   (model_image): CNN(
#     (conv1): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1))
#     (conv2): Conv2d(10, 20, kernel_size=(3, 3), stride=(1, 1))
#     (conv2_drop): Dropout2d(p=0.5, inplace=False)
#     (fc1): Linear(in_features=720, out_features=1024, bias=True)
#     (fc2): Linear(in_features=1024, out_features=256, bias=True)
#   )
#   (lineal1): Linear(in_features=512, out_features=3, bias=True)
# )
#               optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.05
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
#               criterion: CrossEntropyLoss()
#               epocas: 5
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.100.. Test loss: 1.091.. Test accuracy: 0.406
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.087.. Test loss: 1.065.. Test accuracy: 0.422
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.069.. Test loss: 1.043.. Test accuracy: 0.453
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.040.. Test loss: 1.007.. Test accuracy: 0.486
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.013.. Test loss: 0.970.. Test accuracy: 0.517
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.004.. Test loss: 0.945.. Test accuracy: 0.548
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.950.. Test loss: 0.952.. Test accuracy: 0.532
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.946.. Test loss: 0.931.. Test accuracy: 0.567
# Epoch 1/5.. Train loss: 0.937.. Test loss: 0.918.. Test accuracy: 0.579
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.935.. Test loss: 0.938.. Test accuracy: 0.556
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.917.. Test loss: 0.900.. Test accuracy: 0.583
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.904.. Test loss: 0.862.. Test accuracy: 0.607
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.885.. Test loss: 0.884.. Test accuracy: 0.613
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.921.. Test loss: 0.897.. Test accuracy: 0.596
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.923.. Test loss: 0.876.. Test accuracy: 0.607
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.925.. Test loss: 0.884.. Test accuracy: 0.616
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.878.. Test loss: 0.889.. Test accuracy: 0.598
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.862.. Test loss: 0.895.. Test accuracy: 0.599
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.857.. Test loss: 0.913.. Test accuracy: 0.577
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.892.. Test loss: 0.870.. Test accuracy: 0.613
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.862.. Test loss: 0.852.. Test accuracy: 0.623
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.869.. Test loss: 0.885.. Test accuracy: 0.596
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.827.. Test loss: 0.858.. Test accuracy: 0.607
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.843.. Test loss: 0.869.. Test accuracy: 0.594
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.826.. Test loss: 0.850.. Test accuracy: 0.626
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.838.. Test loss: 0.847.. Test accuracy: 0.622
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.833.. Test loss: 0.823.. Test accuracy: 0.639
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.844.. Test loss: 0.861.. Test accuracy: 0.594
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.817.. Test loss: 0.861.. Test accuracy: 0.594
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.826.. Test loss: 0.843.. Test accuracy: 0.623
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.844.. Test loss: 0.824.. Test accuracy: 0.641
# Epoch 1/5.. Train loss: 0.816.. Test loss: 0.824.. Test accuracy: 0.633
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.834.. Test loss: 0.819.. Test accuracy: 0.637
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.830.. Test loss: 0.813.. Test accuracy: 0.635
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.822.. Test loss: 0.849.. Test accuracy: 0.616
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.814.. Test loss: 0.818.. Test accuracy: 0.640
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.837.. Test loss: 0.797.. Test accuracy: 0.644
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.841.. Test loss: 0.804.. Test accuracy: 0.646
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.863.. Test loss: 0.821.. Test accuracy: 0.651
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.804.. Test loss: 0.827.. Test accuracy: 0.629
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.817.. Test loss: 0.845.. Test accuracy: 0.616
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.786.. Test loss: 0.820.. Test accuracy: 0.632
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.800.. Test loss: 0.813.. Test accuracy: 0.642
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.773.. Test loss: 0.848.. Test accuracy: 0.605
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.792.. Test loss: 0.840.. Test accuracy: 0.629
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.813.. Test loss: 0.857.. Test accuracy: 0.608
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.824.. Test loss: 0.808.. Test accuracy: 0.640
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.824.. Test loss: 0.828.. Test accuracy: 0.632
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.780.. Test loss: 0.809.. Test accuracy: 0.630
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.733.. Test loss: 0.849.. Test accuracy: 0.603
# Epoch 2/5.. Train loss: 0.729.. Test loss: 0.786.. Test accuracy: 0.656
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.756.. Test loss: 0.849.. Test accuracy: 0.605
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.762.. Test loss: 0.834.. Test accuracy: 0.612
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.733.. Test loss: 0.823.. Test accuracy: 0.620
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.764.. Test loss: 0.810.. Test accuracy: 0.637
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.744.. Test loss: 0.860.. Test accuracy: 0.584
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.725.. Test loss: 0.776.. Test accuracy: 0.667
# Epoch 2/5.. Train loss: 0.746.. Test loss: 0.801.. Test accuracy: 0.653
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.768.. Test loss: 0.848.. Test accuracy: 0.603
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.749.. Test loss: 0.818.. Test accuracy: 0.626
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.704.. Test loss: 0.776.. Test accuracy: 0.657
# Epoch 2/5.. Train loss: 0.708.. Test loss: 0.839.. Test accuracy: 0.639
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.723.. Test loss: 0.858.. Test accuracy: 0.597
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.751.. Test loss: 0.810.. Test accuracy: 0.644
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.705.. Test loss: 0.774.. Test accuracy: 0.663
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 3/5.. Train loss: 0.704.. Test loss: 0.855.. Test accuracy: 0.599
# Epoch 3/5.. Train loss: 0.758.. Test loss: 0.841.. Test accuracy: 0.600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20036/873685964.py in <module>
#       1 experiment = Train(model, optimizer, criterion,trainloader, testloader, writer=writer, show_matrix = True)
# ----> 2 experiment.train_model()
#
# c:\Users\groso\Desktop\Ramos\Memes\train_model.py in train_model(self)
#      70
#      71                         with torch.no_grad():
# ---> 72                             for image, text, labels in self.test_loader:
#      73
#      74                                 image = image.to(self.device)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\dataset.py in __getitem__(self, idx)
#     309
#     310     def __getitem__(self, idx):
# --> 311         return self.dataset[self.indices[idx]]
#     312
#     313     def __len__(self):
#
# c:\Users\groso\Desktop\Ramos\Memes\data_loader.py in __getitem__(self, index)
#      68
#      69         if self.image_out:
# ---> 70             image = Image.open(image).convert("RGB")
#      71             if self.transform is not None:
#      72                 image = self.transform(image)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py in convert(self, mode, matrix, dither, palette, colors)
#     913         """
#     914
# --> 915         self.load()
#     916
#     917         if not mode and self.mode == "P":
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\ImageFile.py in load(self)
#     253
#     254                             b = b + s
# --> 255                             n, err_code = decoder.decode(b)
#     256                             if n < 0:
#     257                                 break
#
# KeyboardInterrupt:
