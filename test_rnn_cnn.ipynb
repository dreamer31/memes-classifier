# %%
from model import CNN, RNN,  ModelMix
from torch import nn
from data_loader import load_split_data
from torch.optim import SGD, Adam
from torch.utils.tensorboard import SummaryWriter
from utils import get_device

import json

# %%
from train_model import Train

BATCH_SIZE = 128
LEARN_RATE = 0.05
EMBEDDING_DIM = 200

with open('./datainfo.json', 'r') as f:
    data = json.load(f)  
    
vocab = data["vocab"]
vocab_size = len(vocab)
writer = SummaryWriter(comment=f"RNN-Momentum {LEARN_RATE} {BATCH_SIZE}")

trainloader, testloader = load_split_data(data, BATCH_SIZE, .2)

# %%
device = get_device()
model1 = RNN(vocab_size, EMBEDDING_DIM, 256, vocab)
model2 = CNN()
model = ModelMix(model1, model2)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = SGD(model.parameters(), lr=LEARN_RATE, momentum=0.9)

# %%
experiment = Train(model, optimizer, criterion,trainloader, testloader, writer=writer, show_matrix = True)
experiment.train_model()
# Out:
# ==== Iniciando entrenamiento ====
#
# Los parametros a usar son
#               model: ModelMix(
#   (model_text): RNN(
#     (embedding): Embedding(8669, 200, padding_idx=1)
#     (rnn): RNN(200, 256, batch_first=True, bidirectional=True)
#     (label): Linear(in_features=512, out_features=256, bias=True)
#   )
#   (model_image): CNN(
#     (conv1): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1))
#     (conv2): Conv2d(10, 20, kernel_size=(3, 3), stride=(1, 1))
#     (conv2_drop): Dropout2d(p=0.5, inplace=False)
#     (fc1): Linear(in_features=720, out_features=1024, bias=True)
#     (fc2): Linear(in_features=1024, out_features=256, bias=True)
#   )
#   (lineal1): Linear(in_features=512, out_features=3, bias=True)
# )
#               optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.05
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
#               criterion: CrossEntropyLoss()
#               epocas: 5
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.100.. Test loss: 1.091.. Test accuracy: 0.406
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.087.. Test loss: 1.065.. Test accuracy: 0.423
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.069.. Test loss: 1.043.. Test accuracy: 0.453
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.040.. Test loss: 1.007.. Test accuracy: 0.487
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.013.. Test loss: 0.970.. Test accuracy: 0.518
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 1.003.. Test loss: 0.945.. Test accuracy: 0.554
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.954.. Test loss: 0.957.. Test accuracy: 0.535
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.948.. Test loss: 0.919.. Test accuracy: 0.578
# Epoch 1/5.. Train loss: 0.923.. Test loss: 0.900.. Test accuracy: 0.589
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.934.. Test loss: 0.917.. Test accuracy: 0.578
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.912.. Test loss: 0.871.. Test accuracy: 0.612
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.902.. Test loss: 0.861.. Test accuracy: 0.619
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.896.. Test loss: 0.890.. Test accuracy: 0.609
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.921.. Test loss: 0.886.. Test accuracy: 0.593
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.906.. Test loss: 0.900.. Test accuracy: 0.579
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.918.. Test loss: 0.899.. Test accuracy: 0.611
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.890.. Test loss: 0.908.. Test accuracy: 0.586
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.865.. Test loss: 0.901.. Test accuracy: 0.587
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.874.. Test loss: 0.907.. Test accuracy: 0.579
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.914.. Test loss: 0.880.. Test accuracy: 0.609
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.866.. Test loss: 0.853.. Test accuracy: 0.625
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.861.. Test loss: 0.890.. Test accuracy: 0.577
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.819.. Test loss: 0.862.. Test accuracy: 0.603
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.846.. Test loss: 0.872.. Test accuracy: 0.607
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.833.. Test loss: 0.892.. Test accuracy: 0.598
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.843.. Test loss: 0.838.. Test accuracy: 0.632
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.847.. Test loss: 0.867.. Test accuracy: 0.604
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.868.. Test loss: 0.874.. Test accuracy: 0.597
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.816.. Test loss: 0.854.. Test accuracy: 0.603
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.838.. Test loss: 0.855.. Test accuracy: 0.612
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.861.. Test loss: 0.824.. Test accuracy: 0.635
# Epoch 1/5.. Train loss: 0.814.. Test loss: 0.824.. Test accuracy: 0.635
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.845.. Test loss: 0.838.. Test accuracy: 0.633
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.865.. Test loss: 0.844.. Test accuracy: 0.615
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.814.. Test loss: 0.865.. Test accuracy: 0.612
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.807.. Test loss: 0.814.. Test accuracy: 0.634
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2/5.. Train loss: 0.864.. Test loss: 0.820.. Test accuracy: 0.629
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:973: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
