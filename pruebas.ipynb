# %%
import json
from data_loader import load_split_data
import torch
from torchtext.legacy import data, vocab

# %%
import torch
from torchtext.legacy import data
from spacy.lang.es.stop_words import STOP_WORDS
from string import whitespace, punctuation

with open('./datainfo.json', 'r') as f:
    df = json.load(f)  

vocab = df["vocab"]
train_iterator, valid_iterator = load_split_data(df)
len(vocab)
# Out:
# 8670

# %%
# Hyperparameters
num_epochs = 25
learning_rate = 0.001

INPUT_DIM = len(vocab)
EMBEDDING_DIM = 200
HIDDEN_DIM = 256
OUTPUT_DIM = 1
N_LAYERS = 2
BIDIRECTIONAL = True
DROPOUT = 0.2

# %%
from model import LSTMTagger, ModelMix
import torch.nn as nn
from torch import optim

model = ModelMix(EMBEDDING_DIM, len(vocab), 3, vocab)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device) #CNN to GPU
# Out:
# ModelMix(
#   (ModelD): TextSentimentLinear(
#     (embedding): EmbeddingBag(8670, 200, mode=max)
#     (fc): Linear(in_features=200, out_features=256, bias=True)
#   )
#   (ModelE): CNN(
#     (conv1): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1))
#     (conv2): Conv2d(10, 20, kernel_size=(3, 3), stride=(1, 1))
#     (conv2_drop): Dropout2d(p=0.5, inplace=False)
#     (fc1): Linear(in_features=720, out_features=1024, bias=True)
#     (fc2): Linear(in_features=1024, out_features=256, bias=True)
#   )
#   (lineal1): Linear(in_features=512, out_features=3, bias=True)
# )

# %%
def binary_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """

    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division 
    acc = correct.sum() / len(correct)
    return acc

# %%
def train(model, iterator):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for image, text, labels in iterator:
        
        labels = labels.to(device)
        text = text.type(torch.int64).to(device)
        
        optimizer.zero_grad()
        predictions = model(text)
        print(predictions)
        loss = criterion(predictions, labels)
        acc = binary_accuracy(predictions, labels)

        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
import PIL
import os  


def uwu():

    epochs = 5
    steps = 0
    running_loss = 0
    print_every = 1
    train_losses, test_losses = [], []
    

    for epoch in range(epochs):
        try :
            for image, text, labels in train_iterator:
                steps += 1                
            
                image = image.to(device)
                labels = labels.to(device)
                text = text.type(torch.int64).to(device)
                
                optimizer.zero_grad()
                predictions = model(image, text)
                loss = criterion(predictions, labels)
                
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                
                if steps % print_every == 0:
                    test_loss = 0
                    accuracy = 0
                    total = 0
                    model.eval()
                    with torch.no_grad():
                        for image, text, labels in valid_iterator:
                            
                            labels = labels.to(device)
                            text = text.type(torch.int64).to(device)
                            image = image.to(device)
                            
                            optimizer.zero_grad()
                            predictions = model(image, text)
                            
                            loss = criterion(predictions, labels)
                            test_loss += loss.item()
                            
                            val, ind = predictions.max(1)              
                            accuracy += (ind == labels).sum()
                            total += len(labels)

                    train_losses.append(running_loss/len(train_iterator))
                    test_losses.append(test_loss/len(valid_iterator))                    
                    print(f"Epoch {epoch+1}/{epochs}.. "
                        f"Train loss: {running_loss/print_every:.3f}.. "
                        f"Test loss: {test_loss/len(valid_iterator):.3f}.. "
                        f"Test accuracy: {float(accuracy)/float(total):.3f}")
                    running_loss = 0
                    accuracy = 0
                    total =0
                    model.train()
        except PIL.UnidentifiedImageError as error:
            print(error)
            er = str(error).split("'")
            os.remove(er[1])
            uwu()
        
uwu()
# Out:
# Epoch 1/5.. Train loss: 1.068.. Test loss: 0.484.. Test accuracy: 0.685
# C:\Users\groso\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/5.. Train loss: 0.492.. Test loss: 0.919.. Test accuracy: 0.662
# Epoch 1/5.. Train loss: 0.840.. Test loss: 2.091.. Test accuracy: 0.670
# Epoch 1/5.. Train loss: 2.174.. Test loss: 1.204.. Test accuracy: 0.667
# Epoch 1/5.. Train loss: 1.039.. Test loss: 0.526.. Test accuracy: 0.733
# Epoch 1/5.. Train loss: 0.555.. Test loss: 0.449.. Test accuracy: 0.789
# Epoch 1/5.. Train loss: 0.534.. Test loss: 0.419.. Test accuracy: 0.833
# Epoch 1/5.. Train loss: 0.480.. Test loss: 0.406.. Test accuracy: 0.842
# Epoch 1/5.. Train loss: 0.385.. Test loss: 0.397.. Test accuracy: 0.825
# Epoch 1/5.. Train loss: 0.481.. Test loss: 0.412.. Test accuracy: 0.822
# Epoch 1/5.. Train loss: 0.426.. Test loss: 0.550.. Test accuracy: 0.718
# Epoch 1/5.. Train loss: 0.402.. Test loss: 0.388.. Test accuracy: 0.833
# Epoch 1/5.. Train loss: 0.446.. Test loss: 0.374.. Test accuracy: 0.846
# Epoch 1/5.. Train loss: 0.341.. Test loss: 0.397.. Test accuracy: 0.814
# Epoch 1/5.. Train loss: 0.396.. Test loss: 0.362.. Test accuracy: 0.826
# Epoch 1/5.. Train loss: 0.303.. Test loss: 0.346.. Test accuracy: 0.842
# Epoch 1/5.. Train loss: 0.368.. Test loss: 0.346.. Test accuracy: 0.846
# Epoch 1/5.. Train loss: 0.274.. Test loss: 0.372.. Test accuracy: 0.824
# Epoch 1/5.. Train loss: 0.438.. Test loss: 0.486.. Test accuracy: 0.684
# Epoch 1/5.. Train loss: 0.546.. Test loss: 0.871.. Test accuracy: 0.698
# Epoch 1/5.. Train loss: 0.654.. Test loss: 0.364.. Test accuracy: 0.845
# Epoch 1/5.. Train loss: 0.362.. Test loss: 0.355.. Test accuracy: 0.842
# Epoch 1/5.. Train loss: 0.331.. Test loss: 0.370.. Test accuracy: 0.827
# Epoch 1/5.. Train loss: 0.316.. Test loss: 0.336.. Test accuracy: 0.851
# Epoch 1/5.. Train loss: 0.401.. Test loss: 0.344.. Test accuracy: 0.846
# Epoch 1/5.. Train loss: 0.328.. Test loss: 0.398.. Test accuracy: 0.806
# Epoch 1/5.. Train loss: 0.348.. Test loss: 0.359.. Test accuracy: 0.836
# Epoch 1/5.. Train loss: 0.446.. Test loss: 0.535.. Test accuracy: 0.759
# Epoch 1/5.. Train loss: 0.444.. Test loss: 0.395.. Test accuracy: 0.803
# Epoch 1/5.. Train loss: 0.472.. Test loss: 0.582.. Test accuracy: 0.738
# Epoch 1/5.. Train loss: 0.556.. Test loss: 0.414.. Test accuracy: 0.798
# Epoch 1/5.. Train loss: 0.430.. Test loss: 0.432.. Test accuracy: 0.791
# Epoch 1/5.. Train loss: 0.783.. Test loss: 0.630.. Test accuracy: 0.663
# Epoch 1/5.. Train loss: 0.816.. Test loss: 0.415.. Test accuracy: 0.781
# Epoch 1/5.. Train loss: 0.439.. Test loss: 0.387.. Test accuracy: 0.842
# Epoch 1/5.. Train loss: 0.421.. Test loss: 0.373.. Test accuracy: 0.858
# Epoch 1/5.. Train loss: 0.397.. Test loss: 0.367.. Test accuracy: 0.818
# Epoch 1/5.. Train loss: 0.264.. Test loss: 0.369.. Test accuracy: 0.818
# Epoch 1/5.. Train loss: 0.342.. Test loss: 0.351.. Test accuracy: 0.847
# Epoch 1/5.. Train loss: 0.338.. Test loss: 0.372.. Test accuracy: 0.827
# Epoch 1/5.. Train loss: 0.466.. Test loss: 0.345.. Test accuracy: 0.841
# Epoch 1/5.. Train loss: 0.364.. Test loss: 0.369.. Test accuracy: 0.825
# Epoch 1/5.. Train loss: 0.471.. Test loss: 0.440.. Test accuracy: 0.780
# Epoch 1/5.. Train loss: 0.405.. Test loss: 0.349.. Test accuracy: 0.840
# Epoch 1/5.. Train loss: 0.345.. Test loss: 0.340.. Test accuracy: 0.844
# Epoch 1/5.. Train loss: 0.366.. Test loss: 0.351.. Test accuracy: 0.843
# Epoch 1/5.. Train loss: 0.427.. Test loss: 0.466.. Test accuracy: 0.781
# Epoch 1/5.. Train loss: 0.482.. Test loss: 0.335.. Test accuracy: 0.857
# Epoch 1/5.. Train loss: 0.237.. Test loss: 0.335.. Test accuracy: 0.853
# Epoch 1/5.. Train loss: 0.330.. Test loss: 0.322.. Test accuracy: 0.869
# Epoch 1/5.. Train loss: 0.364.. Test loss: 0.325.. Test accuracy: 0.863
# Epoch 1/5.. Train loss: 0.446.. Test loss: 0.325.. Test accuracy: 0.858
# Epoch 1/5.. Train loss: 0.318.. Test loss: 0.324.. Test accuracy: 0.858
# Epoch 1/5.. Train loss: 0.395.. Test loss: 0.332.. Test accuracy: 0.856
# Epoch 1/5.. Train loss: 0.317.. Test loss: 0.317.. Test accuracy: 0.866
# Epoch 1/5.. Train loss: 0.359.. Test loss: 0.388.. Test accuracy: 0.810
# Epoch 1/5.. Train loss: 0.281.. Test loss: 0.317.. Test accuracy: 0.863
# Epoch 1/5.. Train loss: 0.358.. Test loss: 0.327.. Test accuracy: 0.844
# Epoch 1/5.. Train loss: 0.356.. Test loss: 0.405.. Test accuracy: 0.772
# Epoch 1/5.. Train loss: 0.353.. Test loss: 0.478.. Test accuracy: 0.779
# Epoch 1/5.. Train loss: 0.623.. Test loss: 0.644.. Test accuracy: 0.656
# Epoch 1/5.. Train loss: 0.625.. Test loss: 0.390.. Test accuracy: 0.806
# Epoch 1/5.. Train loss: 0.462.. Test loss: 0.337.. Test accuracy: 0.852
# Epoch 1/5.. Train loss: 0.396.. Test loss: 0.332.. Test accuracy: 0.858
# Epoch 1/5.. Train loss: 0.303.. Test loss: 0.318.. Test accuracy: 0.868
# Epoch 1/5.. Train loss: 0.321.. Test loss: 0.345.. Test accuracy: 0.834
# Epoch 1/5.. Train loss: 0.398.. Test loss: 0.322.. Test accuracy: 0.868
# Epoch 1/5.. Train loss: 0.282.. Test loss: 0.332.. Test accuracy: 0.844
# Epoch 1/5.. Train loss: 0.397.. Test loss: 0.518.. Test accuracy: 0.674
# Epoch 1/5.. Train loss: 0.650.. Test loss: 0.531.. Test accuracy: 0.744
# Epoch 1/5.. Train loss: 0.560.. Test loss: 0.382.. Test accuracy: 0.830
# Epoch 1/5.. Train loss: 0.307.. Test loss: 0.342.. Test accuracy: 0.849
# Epoch 1/5.. Train loss: 0.330.. Test loss: 0.337.. Test accuracy: 0.851
# Epoch 1/5.. Train loss: 0.304.. Test loss: 0.336.. Test accuracy: 0.858
# Epoch 1/5.. Train loss: 0.352.. Test loss: 0.395.. Test accuracy: 0.805
# Epoch 1/5.. Train loss: 0.397.. Test loss: 0.323.. Test accuracy: 0.858
# Epoch 1/5.. Train loss: 0.305.. Test loss: 0.318.. Test accuracy: 0.861
# Epoch 1/5.. Train loss: 0.296.. Test loss: 0.363.. Test accuracy: 0.836
# Epoch 1/5.. Train loss: 0.398.. Test loss: 0.325.. Test accuracy: 0.856
# Epoch 1/5.. Train loss: 0.345.. Test loss: 0.338.. Test accuracy: 0.836
# Epoch 1/5.. Train loss: 0.398.. Test loss: 0.361.. Test accuracy: 0.837
# Epoch 1/5.. Train loss: 0.357.. Test loss: 0.361.. Test accuracy: 0.824
# Epoch 1/5.. Train loss: 0.298.. Test loss: 0.316.. Test accuracy: 0.859
# Epoch 1/5.. Train loss: 0.358.. Test loss: 0.315.. Test accuracy: 0.856
# Epoch 1/5.. Train loss: 0.328.. Test loss: 0.381.. Test accuracy: 0.803
# Epoch 1/5.. Train loss: 0.363.. Test loss: 0.338.. Test accuracy: 0.841
# Epoch 1/5.. Train loss: 0.333.. Test loss: 0.381.. Test accuracy: 0.804
# Epoch 1/5.. Train loss: 0.278.. Test loss: 0.311.. Test accuracy: 0.856
# Epoch 1/5.. Train loss: 0.278.. Test loss: 0.330.. Test accuracy: 0.848
# Epoch 1/5.. Train loss: 0.518.. Test loss: 0.337.. Test accuracy: 0.839
# Epoch 1/5.. Train loss: 0.448.. Test loss: 0.379.. Test accuracy: 0.803
# Epoch 1/5.. Train loss: 0.246.. Test loss: 0.304.. Test accuracy: 0.866
# Epoch 1/5.. Train loss: 0.310.. Test loss: 0.318.. Test accuracy: 0.858
# Epoch 1/5.. Train loss: 0.295.. Test loss: 0.339.. Test accuracy: 0.842
# Epoch 1/5.. Train loss: 0.325.. Test loss: 0.428.. Test accuracy: 0.753
# Epoch 1/5.. Train loss: 0.440.. Test loss: 0.468.. Test accuracy: 0.788
# Epoch 1/5.. Train loss: 0.507.. Test loss: 0.378.. Test accuracy: 0.814
# Epoch 1/5.. Train loss: 0.346.. Test loss: 0.335.. Test accuracy: 0.851
# Epoch 1/5.. Train loss: 0.313.. Test loss: 0.319.. Test accuracy: 0.865
# Epoch 1/5.. Train loss: 0.377.. Test loss: 0.312.. Test accuracy: 0.865
# Epoch 1/5.. Train loss: 0.326.. Test loss: 0.304.. Test accuracy: 0.866
# Epoch 1/5.. Train loss: 0.257.. Test loss: 0.306.. Test accuracy: 0.870
# Epoch 1/5.. Train loss: 0.216.. Test loss: 0.321.. Test accuracy: 0.855
# Epoch 1/5.. Train loss: 0.267.. Test loss: 0.300.. Test accuracy: 0.864
# Epoch 1/5.. Train loss: 0.310.. Test loss: 0.297.. Test accuracy: 0.882
# Epoch 1/5.. Train loss: 0.409.. Test loss: 0.341.. Test accuracy: 0.844
# Epoch 1/5.. Train loss: 0.527.. Test loss: 0.708.. Test accuracy: 0.667
# Epoch 1/5.. Train loss: 0.743.. Test loss: 0.498.. Test accuracy: 0.769
# Epoch 1/5.. Train loss: 0.470.. Test loss: 0.341.. Test accuracy: 0.844
# Epoch 1/5.. Train loss: 0.267.. Test loss: 0.312.. Test accuracy: 0.875
# Epoch 1/5.. Train loss: 0.313.. Test loss: 0.312.. Test accuracy: 0.878
# Epoch 1/5.. Train loss: 0.319.. Test loss: 0.306.. Test accuracy: 0.861
# Epoch 1/5.. Train loss: 0.270.. Test loss: 0.305.. Test accuracy: 0.875
# Epoch 1/5.. Train loss: 0.312.. Test loss: 0.302.. Test accuracy: 0.855
# Epoch 1/5.. Train loss: 0.238.. Test loss: 0.299.. Test accuracy: 0.867

# %%
import time

t = time.time()
loss=[]
acc=[]
val_acc=[]

for epoch in range(num_epochs):
    
    train_loss, train_acc = train(model, train_iterator)
    valid_acc = evaluate(model, valid_iterator)
    
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Acc: {valid_acc*100:.2f}%')
    
    loss.append(train_loss)
    acc.append(train_acc)
    val_acc.append(valid_acc)
    
print(f'time:{time.time()-t:.3f}')
